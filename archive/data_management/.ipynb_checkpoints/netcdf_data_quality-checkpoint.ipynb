# %%
# import modules

import xarray as xr
import cmocean
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.dates as pldates
import scipy.signal as sig
import numpy as np
import pandas as pd
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
for i in range(2):
    # %matplotlib notebook

# %%
avg='raw'
ds = xr.open_dataset('../../../Data/Raw/Axis75_Oct1_Dec1_2013/BarkleyCanyon_BarkleyCanyonAxis_AcousticDopplerCurrentProfiler75kHz_20131010T000001Z_20131010T235958Z-binMapNearest_3beamOn.nc')
#avg='15-min'
#ds = xr.open_dataset('../../../Data/Raw/Axis75_Oct1_Dec1_2013/BarkleyCanyon_BarkleyCanyonAxis_AcousticDopplerCurrentProfiler75kHz_20131010T000000Z_20131011T000000Z-Ensemble900s_binMapNearest_3beamOn.nc')
#avg='15-min 50 false-target thres.'
#ds = xr.open_dataset('../../../Data/Raw/Axis75_Oct1_Dec1_2013/BarkleyCanyon_BarkleyCanyonAxis_AcousticDopplerCurrentProfiler75kHz_20131010T000000Z_20131011T000000Z-Ensemble900s_binMapNearest_3beamOn_falseTar50.nc')

ds = ds.sel(time=slice('2013-10-10T14:00:00','2013-10-10T19:00:00'))
ds.variables
# Out:
# Frozen({'time': <xarray.IndexVariable 'time' (time: 9001)>
# array(['2013-10-10T14:00:00.340003584', '2013-10-10T14:00:02.340002816',
#        '2013-10-10T14:00:04.340002048', ..., '2013-10-10T18:59:56.599994880',
#        '2013-10-10T18:59:58.599994112', '2013-10-10T19:00:00.599993344'],
#       dtype='datetime64[ns]')
# Attributes:
#     sdn_parameter_name:  time
#     long_name:           time
#     axis:                T, 'binmap_depth': <xarray.Variable (depth: 80)>
# array([968.27, 960.27, 952.27, 944.27, 936.27, 928.27, 920.27, 912.27, 904.27,
#        896.27, 888.27, 880.27, 872.27, 864.27, 856.27, 848.27, 840.27, 832.27,
#        824.27, 816.27, 808.27, 800.27, 792.27, 784.27, 776.27, 768.27, 760.27,
#        752.27, 744.27, 736.27, 728.27, 720.27, 712.27, 704.27, 696.27, 688.27,
#        680.27, 672.27, 664.27, 656.27, 648.27, 640.27, 632.27, 624.27, 616.27,
#        608.27, 600.27, 592.27, 584.27, 576.27, 568.27, 560.27, 552.27, 544.27,
#        536.27, 528.27, 520.27, 512.27, 504.27, 496.27, 488.27, 480.27, 472.27,
#        464.27, 456.27, 448.27, 440.27, 432.27, 424.27, 416.27, 408.27, 400.27,
#        392.27, 384.27, 376.27, 368.27, 360.27, 352.27, 344.27, 336.27],
#       dtype=float32)
# Attributes:
#     sdn_parameter_name:  depth
#     long_name:           water depth of final velocity measurement bins
#     units:               meters
#     axis:                Z
#     positive:            down
#     comment:             Water depth for the u (east), v (north), w (up), vel..., 'depth': <xarray.IndexVariable 'depth' (depth: 80)>
# array([968.27094, 960.2714 , 952.27185, 944.27234, 936.27277, 928.2732 ,
#        920.2737 , 912.2741 , 904.2746 , 896.275  , 888.2755 , 880.27594,
#        872.27637, 864.27686, 856.2773 , 848.2778 , 840.2782 , 832.2787 ,
#        824.2791 , 816.27954, 808.28   , 800.28046, 792.28094, 784.2814 ,
#        776.28186, 768.2823 , 760.2827 , 752.2832 , 744.2836 , 736.2841 ,
#        728.28455, 720.28503, 712.28546, 704.2859 , 696.2864 , 688.2868 ,
#        680.2873 , 672.2877 , 664.2882 , 656.28864, 648.28906, 640.28955,
#        632.29   , 624.29047, 616.2909 , 608.2914 , 600.2918 , 592.29224,
#        584.2927 , 576.29315, 568.29364, 560.29407, 552.29456, 544.295  ,
#        536.2954 , 528.2959 , 520.2963 , 512.2968 , 504.29724, 496.2977 ,
#        488.29816, 480.2986 , 472.29907, 464.29953, 456.29996, 448.3004 ,
#        440.30087, 432.30133, 424.3018 , 416.30225, 408.3027 , 400.30316,
#        392.3036 , 384.30405, 376.3045 , 368.30496, 360.30542, 352.30588,
#        344.30634, 336.30676], dtype=float32)
# Attributes:
#     sdn_parameter_name:  depth
#     long_name:           water depth of beam-averaged measurement bins, tilt-...
#     units:               meters
#     axis:                Z
#     positive:            down
#     comment:             Water depth of measurement bins corrected for tilt, ..., 'range': <xarray.Variable (depth: 80)>
# array([ 16.73,  24.73,  32.73,  40.73,  48.73,  56.73,  64.73,  72.73,  80.73,
#         88.73,  96.73, 104.73, 112.73, 120.73, 128.73, 136.73, 144.73, 152.73,
#        160.73, 168.73, 176.73, 184.73, 192.73, 200.73, 208.73, 216.73, 224.73,
#        232.73, 240.73, 248.73, 256.73, 264.73, 272.73, 280.73, 288.73, 296.73,
#        304.73, 312.73, 320.73, 328.73, 336.73, 344.73, 352.73, 360.73, 368.73,
#        376.73, 384.73, 392.73, 400.73, 408.73, 416.73, 424.73, 432.73, 440.73,
#        448.73, 456.73, 464.73, 472.73, 480.73, 488.73, 496.73, 504.73, 512.73,
#        520.73, 528.73, 536.73, 544.73, 552.73, 560.73, 568.73, 576.73, 584.73,
#        592.73, 600.73, 608.73, 616.73, 624.73, 632.73, 640.73, 648.73],
#       dtype=float32)
# Attributes:
#     sdn_parameter_name:  range
#     long_name:           range from transducer
#     units:               meters
#     axis:                Z
#     comment:             Range of measurement bins from the transducer, appli..., 'latitude': <xarray.IndexVariable 'latitude' (latitude: 1)>
# array([48.316517], dtype=float32)
# Attributes:
#     sdn_parameter_name:  latitude
#     long_name:           latitude
#     units:               degrees_north
#     axis:                Y, 'longitude': <xarray.IndexVariable 'longitude' (longitude: 1)>
# array([-126.05022], dtype=float32)
# Attributes:
#     sdn_parameter_name:  longitude
#     long_name:           longitude
#     units:               degrees_east
#     axis:                X, 'u': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  eastward_sea_water_velocity
#     long_name:           eastward sea water velocity
#     units:               meters/second, 'v': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  northward_sea_water_velocity
#     long_name:           northward sea water velocity
#     units:               meters/second, 'w': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  upward_sea_water_velocity
#     long_name:           upward sea water velocity
#     units:               meters/second, 'velocityError': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  indicative_error_from_multibeam_acoustic_doppler_vel...
#     long_name:           acoustic doppler current profiler error velocity
#     units:               meters/second, 'meanBackscatter': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_nam:  sound_intensity_level_in_water
#     long_name:          acoustic doppler current profiler beam-averaged corre...
#     units:              dB
#     comment:            beam averaged and corrected for two-way beam spreadin..., 'intens_beam1': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  signal_intensity_from_multibeam_acoustic_doppler_vel...
#     long_name:           acoustic doppler current profiler return signal stre...
#     units:               counts, 'intens_beam2': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  signal_intensity_from_multibeam_acoustic_doppler_vel...
#     long_name:           acoustic doppler current profiler return signal stre...
#     units:               counts, 'intens_beam3': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  signal_intensity_from_multibeam_acoustic_doppler_vel...
#     long_name:           acoustic doppler current profiler return signal stre...
#     units:               counts, 'intens_beam4': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  signal_intensity_from_multibeam_acoustic_doppler_vel...
#     long_name:           acoustic doppler current profiler return signal stre...
#     units:               counts, 'corr_beam1': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  beam_consistency_indicator_from_multibeam_acoustic_d...
#     long_name:           acoustic doppler current profiler correlation magnit...
#     units:               counts, 'corr_beam2': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  beam_consistency_indicator_from_multibeam_acoustic_d...
#     long_name:           acoustic doppler current profiler correlation magnit...
#     units:               counts, 'corr_beam3': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  beam_consistency_indicator_from_multibeam_acoustic_d...
#     long_name:           acoustic doppler current profiler correlation magnit...
#     units:               counts, 'corr_beam4': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  beam_consistency_indicator_from_multibeam_acoustic_d...
#     long_name:           acoustic doppler current profiler correlation magnit...
#     units:               counts, 'percentGood_beam1': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  proportion_of_acceptable_signal_returns_from_acousti...
#     long_name:           acoustic doppler current profiler percent good beam 1
#     units:               percent, 'percentGood_beam2': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  proportion_of_acceptable_signal_returns_from_acousti...
#     long_name:           acoustic doppler current profiler percent good beam 2
#     units:               percent, 'percentGood_beam3': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  proportion_of_acceptable_signal_returns_from_acousti...
#     long_name:           acoustic doppler current profiler percent good beam 3
#     units:               percent, 'percentGood_beam4': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  proportion_of_acceptable_signal_returns_from_acousti...
#     long_name:           acoustic doppler current profiler percent good beam 4
#     units:               percent, 'velocity_beam1': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  radial_sea_water_velocity_away_from_instrument
#     long_name:           radial velocity beam 1
#     units:               meters/second, 'velocity_beam2': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  radial_sea_water_velocity_away_from_instrument
#     long_name:           radial velocity beam 2
#     units:               meters/second, 'velocity_beam3': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  radial_sea_water_velocity_away_from_instrument
#     long_name:           radial velocity beam 3
#     units:               meters/second, 'velocity_beam4': <xarray.Variable (time: 9001, depth: 80)>
# [720080 values with dtype=float32]
# Attributes:
#     sdn_parameter_name:  radial_sea_water_velocity_away_from_instrument
#     long_name:           radial velocity beam 4
#     units:               meters/second, 'temperature': <xarray.Variable (time: 9001)>
# array([276.78, 276.84, 276.82, ..., 276.86, 276.85, 276.82], dtype=float32)
# Attributes:
#     sdn_parameter_name:  sea_water_temperature
#     long_name:           sea water temperature
#     units:               K, 'pitch': <xarray.Variable (time: 9001)>
# array([-0.6 , -0.62, -0.63, ..., -0.58, -0.61, -0.61], dtype=float32)
# Attributes:
#     sdn_parameter_name:  platform_pitch_angle
#     long_name:           pitch
#     units:               degrees, 'roll': <xarray.Variable (time: 9001)>
# array([-0.05, -0.04, -0.07, ..., -0.03, -0.06, -0.06], dtype=float32)
# Attributes:
#     sdn_parameter_name:  platform_roll_angle
#     long_name:           roll
#     units:               degrees})

# %%
# plot u velocity

fig,ax0 = plt.subplots(1,1,figsize=(13,5))
vmin=-0.15
vmax=0.15
im0 = ax0.pcolormesh(ds.time, -ds.depth, ds.u.T, rasterized=True, cmap='RdBu_r', vmin=vmin, vmax=vmax,shading='auto')
cbar0 = fig.colorbar(im0, ax=ax0, fraction=0.05, pad=0.01, aspect=40, extend='both')
cbar0.set_label('[m/s]')
ax0.set_xlabel('Time [mm-dd hh]')
ax0.set_ylabel('Depth [m]')
ax0.set_title(rf'$u$ ({avg})')
date_form = pldates.DateFormatter("%m-%d %H")
ax0.xaxis.set_major_formatter(date_form)
ax0.xaxis.set_major_locator(plt.MaxNLocator(6))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1300">

# %%
# plot mean backscatter

fig,ax0 = plt.subplots(1,1,figsize=(13,5))
vmin=85
vmax=105
im0 = ax0.pcolormesh(ds.time, -ds.depth, ds.meanBackscatter.T, rasterized=True, cmap='plasma_r', vmin=vmin, vmax=vmax,shading='auto')
cbar0 = fig.colorbar(im0, ax=ax0, fraction=0.05, pad=0.01, aspect=40, extend='both')
cbar0.set_label('[counts]')
ax0.set_xlabel('Time [mm-dd hh]')
ax0.set_ylabel('Depth [m]')
ax0.set_title(rf'Mean backscatter ({avg})')
date_form = pldates.DateFormatter("%m-%d %H")
ax0.xaxis.set_major_formatter(date_form)
ax0.xaxis.set_major_locator(plt.MaxNLocator(6))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1300">

# %%
# plot beam intensity data

fig,((ax0,ax1),(ax2,ax3)) = plt.subplots(2,2,figsize=(13,5),sharex=True,sharey=True)
fig.subplots_adjust(wspace=0.03,hspace=0.2)
vmin=55
vmax=120
im0 = ax0.pcolormesh(ds.time, -ds.depth, ds.intens_beam1.T, rasterized=True, cmap='plasma', vmin=vmin, vmax=vmax,shading='auto')
im1 = ax1.pcolormesh(ds.time, -ds.depth, ds.intens_beam2.T, rasterized=True, cmap='plasma', vmin=vmin, vmax=vmax,shading='auto')
im2 = ax2.pcolormesh(ds.time, -ds.depth, ds.intens_beam3.T, rasterized=True, cmap='plasma', vmin=vmin, vmax=vmax,shading='auto')
im3 = ax3.pcolormesh(ds.time, -ds.depth, ds.intens_beam4.T, rasterized=True, cmap='plasma', vmin=vmin, vmax=vmax,shading='auto')
cbar1 = fig.colorbar(im1, ax=ax1, fraction=0.05, pad=0.01, aspect=40, extend='both')
cbar1.set_label('[counts]')
cbar3 = fig.colorbar(im3, ax=ax3, fraction=0.05, pad=0.01, aspect=40, extend='both')
cbar3.set_label('[counts]')
ax2.set_xlabel('Time [mm-dd hh]')
ax3.set_xlabel('Time [mm-dd hh]')
ax0.set_ylabel('Depth [m]')
ax2.set_ylabel('Depth [m]')
ax0.set_title(rf'Beam1 intensity ({avg})')
ax1.set_title(rf'Beam2 intensity ({avg})')
ax2.set_title(rf'Beam3 intensity ({avg})')
ax3.set_title(rf'Beam4 intensity ({avg})')
date_form = pldates.DateFormatter("%m-%d %H")
ax2.xaxis.set_major_formatter(date_form)
ax2.xaxis.set_major_locator(plt.MaxNLocator(6))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1300">

# %%
# plot correlation data

fig,((ax0,ax1),(ax2,ax3)) = plt.subplots(2,2,figsize=(13,5),sharex=True,sharey=True)
fig.subplots_adjust(wspace=0.03,hspace=0.2)
vmin=75
vmax=130
im0 = ax0.pcolormesh(ds.time, -ds.depth, ds.corr_beam1.T, rasterized=True, cmap='plasma', vmin=vmin, vmax=vmax,shading='auto')
im1 = ax1.pcolormesh(ds.time, -ds.depth, ds.corr_beam2.T, rasterized=True, cmap='plasma', vmin=vmin, vmax=vmax,shading='auto')
im2 = ax2.pcolormesh(ds.time, -ds.depth, ds.corr_beam3.T, rasterized=True, cmap='plasma', vmin=vmin, vmax=vmax,shading='auto')
im3 = ax3.pcolormesh(ds.time, -ds.depth, ds.corr_beam4.T, rasterized=True, cmap='plasma', vmin=vmin, vmax=vmax,shading='auto')
cbar1 = fig.colorbar(im1, ax=ax1, fraction=0.05, pad=0.01, aspect=40, extend='both')
cbar1.set_label('[counts]')
cbar3 = fig.colorbar(im3, ax=ax3, fraction=0.05, pad=0.01, aspect=40, extend='both')
cbar3.set_label('[counts]')
ax2.set_xlabel('Time [mm-dd hh]')
ax3.set_xlabel('Time [mm-dd hh]')
ax0.set_ylabel('Depth [m]')
ax2.set_ylabel('Depth [m]')
ax0.set_title(rf'Beam1 correlation ({avg})')
ax1.set_title(rf'Beam2 correlation ({avg})')
ax2.set_title(rf'Beam3 correlation ({avg})')
ax3.set_title(rf'Beam4 correlation ({avg})')
date_form = pldates.DateFormatter("%m-%d %H")
ax2.xaxis.set_major_formatter(date_form)
ax2.xaxis.set_major_locator(plt.MaxNLocator(6))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1300">
