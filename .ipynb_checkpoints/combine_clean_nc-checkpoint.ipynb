# %%
import xarray as xr
import datetime
import cmath
from datetime import datetime
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import matplotlib.dates as pldates
import numpy as np
import scipy.signal as sig
import scipy.integrate as integ
import scipy.interpolate as interp
import pandas as pd
import seawater as sea
from scipy.stats import chi2
from scipy.io import loadmat
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
# %matplotlib notebook

# %%
ds = xr.open_dataset('../Data/AxisAll/Axis55/1234.nc')
ds = ds.sortby('depth', ascending=True)
#ds = ds.drop_dims('longitude')
#ds = ds.drop_dims('latitude')

ds0 = xr.open_dataset('../Data/AxisAll/Axis55/Axis55_5.nc')
ds0 = ds0.sortby('depth', ascending=True)
ds0 = ds0.drop_dims('longitude')
ds0 = ds0.drop_dims('latitude')

ds1 = xr.combine_by_coords([ds0, ds])
ds1.to_netcdf('../Data/AxisAll/Axis55/12345.nc')
print(ds1)
# Out:
# <xarray.Dataset>
# Dimensions:   (depth: 239, time: 102644)
# Coordinates:
#   * depth     (depth) float64 -309.2 -307.0 -289.2 -287.0 ... 970.8 973.0 975.8
#   * time      (time) datetime64[ns] 2017-01-18T19:07:30.000009984 ... 2019-12-24T01:07:30.000009984
# Data variables:
#     u         (time, depth) float32 nan nan nan nan ... nan nan 0.13705869
#     v         (time, depth) float32 nan nan nan nan ... nan nan -0.272678
#     w         (time, depth) float32 nan nan nan nan ... nan nan -0.07836986
#     pressure  (depth, time) float32 nan nan nan ... 971.84985 971.86487
#     temp      (depth, time) float32 nan nan nan ... 278.0607 278.07025 278.06

# %%
plt.plot(ds.time,ds.u)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...
